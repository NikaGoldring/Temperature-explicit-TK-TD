# %% [markdown]
# # Introduction
#
# This Jupyter Notebook contains the code used to produce the figures within the research article by Mangold-Döring et al. 2022 (https://doi.org/).
#
#
# ## What is plotted here?
# For the model code that generated the predictions plotted below, see the MatLab code in the GitHub repository.
#
# ## Why though?
# For additional information on the research, please refer to the original article and its supporting information: Mangold-Döring et al. (submitted to ES&T in 2022).
#
# ### You think this code is ugly?
# Well, that makes two of us. If you have time to clean it up, please consider to share your tidy version with the rest of us <3!

# %% [markdown]
# # Initial settings
# #### Load packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Define plot specifications

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False  #no line on the right side of the plot
mpl.rcParams['axes.spines.top'] = False    #no line on the top of the plot
mpl.rcParams['font.size'] = '15'           #define font size to 15

# %% [markdown]
# #### Read data from txt files
# First, the TK standard models

# %%
#IMI-models ###############################################################################################################
filename = '20220125_IMI_standard_07.txt' #parent
data_array = np.loadtxt(filename, delimiter=',', dtype=float)
#print(data_array)

filename1 = '20220506_IMI_parent_18.txt' #parent
data_array1 = np.loadtxt(filename1, delimiter=',', dtype=float)
#print(data_array1)

filename2 = '20220506_IMI_parent_24.txt' #parent 
data_array2 = np.loadtxt(filename2, delimiter=',', dtype=float)
#print(data_array2)

# filename12 = '20220506_IMI_metabolite_18.txt' #metabolite  Not used
# data_array12 = np.loadtxt(filename12, delimiter=',', dtype=float)
# #print(data_array12)

# filename13 = '20220506_IMI_metabolite_24.txt' #metabolite  Not used
# data_array13 = np.loadtxt(filename13, delimiter=',', dtype=float)
# #print(data_array13)

#FPF-models ###############################################################################################################
filename3 = '20220125_FPF_standard_07.txt' 
data_array3 = np.loadtxt(filename3, delimiter=',', dtype=float)
#print(data_array3)

filename4 = '20220125_FPF_standard_18.txt' 
data_array4 = np.loadtxt(filename4, delimiter=',', dtype=float)
#print(data_array4)

filename5 = '20220125_FPF_standard_24.txt' 
data_array5 = np.loadtxt(filename5, delimiter=',', dtype=float)
#print(data_array5)

# %% [markdown]
# Now, the TK-T models

# %%
#IMI-models ## TK-T #######################################################################################################
filename6 = '20220726_TK_T_IMI_07.txt' #parent & metabolite
data_array6 = np.loadtxt(filename6, delimiter=',', dtype=float)
#print(data_array6)

filename7 = '20220726_TK_T_IMI_18.txt' #parent & metabolite
data_array7 = np.loadtxt(filename7, delimiter=',', dtype=float)
#print(data_array7)

filename8 = '20220726_TK_T_IMI_24.txt' #parent & metabolite
data_array8 = np.loadtxt(filename8, delimiter=',', dtype=float)
#print(data_array8)

#FPF-models ## TK-T #######################################################################################################
filename9 = '20220726_TK_T_FPF_07.txt' 
data_array9 = np.loadtxt(filename9, delimiter=',', dtype=float)
#print(data_array9)

filename10 = '20220726_TK_T_FPF_18.txt' 
data_array10 = np.loadtxt(filename10, delimiter=',', dtype=float)
#print(data_array10)

filename11 = '20220726_TK_T_FPF_24.txt' 
data_array11 = np.loadtxt(filename11, delimiter=',', dtype=float)
#print(data_array11)

# %% [markdown]
# #### Convert imported array into df

# %%
###IMI-models #############################################################################################################
##TK ######################################################################################################################
df = pd.DataFrame(data=data_array, 
                  columns=["time","upCI","lowCI","model"])

#print(df)

df1 = pd.DataFrame(data=data_array1, 
                  columns=["time","upCI","lowCI","model"])
#print(df1)

df2 = pd.DataFrame(data=data_array2, 
                  columns=["time","upCI","lowCI","model"])
#print(df2)

## TK-T ###################################################################################################################
df6 = pd.DataFrame(data=data_array6, 
                  columns=["time","upCI","lowCI","model","M_upCI","M_lowCI","M_model"])
#print(df6)

df7 = pd.DataFrame(data=data_array7, 
                  columns=["time","upCI","lowCI","model","M_upCI","M_lowCI","M_model"])
#print(df7)

df8 = pd.DataFrame(data=data_array8, 
                  columns=["time","upCI","lowCI","model","M_upCI","M_lowCI","M_model"])
#print(df8)

# %%
###FPF-models #############################################################################################################
##TK ######################################################################################################################
df3 = pd.DataFrame(data=data_array3, 
                  columns=["time","upCI","lowCI","model"])
#print(df3)

df4 = pd.DataFrame(data=data_array4, 
                  columns=["time","upCI","lowCI","model"])
#print(df4)

df5 = pd.DataFrame(data=data_array5, 
                  columns=["time","upCI","lowCI","model"])
#print(df5)

## TK-T ###################################################################################################################
df9 = pd.DataFrame(data=data_array9, 
                  columns=["time","upCI","lowCI","model"])
#print(df9)

df10 = pd.DataFrame(data=data_array10, 
                  columns=["time","upCI","lowCI","model"])
#print(df10)

df11 = pd.DataFrame(data=data_array11, 
                  columns=["time","upCI","lowCI","model"])
#print(df11)

# %% [markdown]
# #### Import measured raw data

# %%
IMI_07 = [[0.26, 11.16,  6.68, 19.29],
          [1.00, 32.56, 44.23, 28.37],
          [2.01, 64.18, 64.22, 57.20],
          [3.00, 54.03, 43.32, 59.00],
          [3.99, 46.85, 70.16, 50.28],
          [5.02, 57.44, 50.88, 62.34]]

IMI_18 = [[0.27, 12.96, 15.35, 22.09],
          [0.99, 51.81, 47.85, 63.17],
          [1.95, 88.79, 86.77, 90.76],
          [2.88, 75.66, 72.46, 82.08],
          [3.87, 76.14, 69.32, 71.35],
          [4.99, 62.34, 62.90, 67.42]]

IMIole_18 = [[2.88, 2.62, 1.71, 2.38],
             [3.87, 1.87, 2.14, 2.13],
             [4.99, 2.78, 1.67, 2.98]]

IMI_24 = [[0.24, 16.95, 23.40,  23.83],
          [1.01, 69.93, 74.25,  64.62],
          [1.99, 93.05, 95.68, 112.35],
          [2.94, 68.56, 92.55,  68.71],
          [3.93, 69.47, 65.31,  67.15],
          [5.08, 55.05, 65.18,  57.53]]

IMIole_24 = [[1.99, 2.96, 3.29, 3.59],
             [2.94, 3.04, 6.06, 5.03],
             [3.93, 4.40, 4.28, 4.01],
             [5.08, 3.01, 4.59, 4.21]]

# Transfer the data to dataframes
data_IMI_07 = pd.DataFrame(data=IMI_07, 
                  columns=["time","rep1","rep2","rep3"])

data_IMI_18 = pd.DataFrame(data=IMI_18, 
                  columns=["time","rep1","rep2","rep3"])
data_IMIole_18 = pd.DataFrame(data=IMIole_18, 
                  columns=["time","rep1","rep2","rep3"])

data_IMI_24 = pd.DataFrame(data=IMI_24, 
                  columns=["time","rep1","rep2","rep3"])
data_IMIole_24 = pd.DataFrame(data=IMIole_24, 
                  columns=["time","rep1","rep2","rep3"])

# %%
FPF_07 = [[0.27,  7.39,  6.65,  5.18],
          [1.00, 30.59, 17.51, 23.44],
          [2.03, 62.94, 44.62, 31.70],
          [2.99, 32.72, 25.43, 52.62],
          [3.98, 40.31, 39.03, 29.56],
          [5.00, 19.50, 31.79, 42.60]]

FPF_18 = [[0.28,  9.42,  8.97, 12.41],
          [1.00, 25.46, 26.47, 24.27],
          [1.92, 36.49, 46.21, 44.74],
          [2.88, 33.20, 43.04, 35.37],
          [3.88, 37.98, 32.94, 32.62],
          [4.99, 22.94, 36.06, 31.97]]

FPF_24 = [[0.25, 10.00, 10.34, 11.97],
          [1.00, 39.51, 33.98, 25.33],
          [1.97, 36.56, 40.69, 42.12],
          [2.93, 25.72, 33.23, 31.33],
          [3.93, 18.36, 23.68, 23.75],
          [5.08, 14.95, 14.62, 16.54]]

# Transfer the data to dataframes
data_FPF_07 = pd.DataFrame(data=FPF_07, 
                  columns=["time","rep1","rep2","rep3"])

data_FPF_18 = pd.DataFrame(data=FPF_18, 
                  columns=["time","rep1","rep2","rep3"])

data_FPF_24 = pd.DataFrame(data=FPF_24, 
                  columns=["time","rep1","rep2","rep3"])

# %% [markdown]
# ## 3. Plot
#
# ### Let's get this data plotted
#
# Figure 3: TK standard vs TK-T models for parent compound

# %%
#Figure 3

fig, ((ax1, ax2, ax3,), 
      ( ax4, ax5, ax6 ))  = plt.subplots(2, 3, ##defining the number of plots (row, columns)
                                        sharex=True, sharey=True,##'row',  
                                        figsize=(20,10))

#Labels 
plt.rc('font', size=15)          # controls default text sizes
ax1.set_ylabel(r'Internal concentration'
               '\n'  # Newline
               r'of imidacloprid [µg '+u"\u00B7"+' $\mathregular{kg^{-1}}$]') # middle dot symbol: u"\u00B7", kg^-1 = $\mathregular{kg^{-1}}$
ax4.set_ylabel(r'Internal concentration'
               '\n'  # Newline
               r'of flupyradifurone [µg '+u"\u00B7"+' $\mathregular{kg^{-1}}$]') # middle dot symbol: u"\u00B7", kg^-1 = $\mathregular{kg^{-1}}$
ax4.set_xlabel('Time [day]')
ax5.set_xlabel('Time [day]')
ax6.set_xlabel('Time [day]')


###############################################################################################################################
### IMI Models
#7
#TK-Standard
ax1.text(0, 130,'A1', fontsize = 15, weight = 'bold')
ax1.plot(df.time, df.model, color= 'b') 
ax1.plot(df.time, df.upCI, color= 'b', linestyle= ':') 
ax1.plot(df.time, df.lowCI, color= 'b', linestyle= ':')
ax1.fill_between(df.time, df.upCI, df.lowCI, color= 'b', alpha = 0.1)

#TK-T
ax1.plot(df6.time, df6.model, color= 'r') 
ax1.plot(df6.time, df6.upCI, color= 'r', linestyle= ':') 
ax1.plot(df6.time, df6.lowCI, color= 'r', linestyle= ':') 
ax1.fill_between(df6.time, df6.upCI, df6.lowCI, color= 'red', alpha = 0.1)

#Raw data
ax1.set_title('7 '+u'\u00B0'+'C')
ax1.errorbar(data_IMI_07.time, data_IMI_07.rep1, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax1.errorbar(data_IMI_07.time, data_IMI_07.rep2, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax1.errorbar(data_IMI_07.time, data_IMI_07.rep3, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax1.vlines(2.01, ymin=0, ymax=140, colors='gray', linestyles='solid', label='') # Vertical line to highlight transition from uptake to elimination phase

#18
#TK-Standard
ax2.text(0, 130,'A2', fontsize = 15, weight = 'bold')
ax2.plot(df1.time, df1.model, color= 'b') 
ax2.plot(df1.time, df1.upCI, color= 'b', linestyle= ':') 
ax2.plot(df1.time, df1.lowCI, color= 'b', linestyle= ':')
ax2.fill_between(df1.time, df1.upCI, df1.lowCI, color= 'b', alpha = 0.1)

#TK-T
ax2.plot(df7.time, df7.model, color= 'r') 
ax2.plot(df7.time, df7.upCI, color= 'r', linestyle= ':') 
ax2.plot(df7.time, df7.lowCI, color= 'r', linestyle= ':') 
ax2.fill_between(df7.time, df7.upCI, df7.lowCI, color= 'red', alpha = 0.1)

#Raw data
ax2.set_title('18 '+u'\u00B0'+'C')
ax2.errorbar(data_IMI_18.time, data_IMI_18.rep1, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax2.errorbar(data_IMI_18.time, data_IMI_18.rep2, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax2.errorbar(data_IMI_18.time, data_IMI_18.rep3, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax2.vlines(1.95, ymin=0, ymax=140, colors='gray', linestyles='solid', label='') # Vertical line to highlight transition from uptake to elimination phase

#24
#TK-Standard
ax3.text(0, 130,'A3', fontsize = 15, weight = 'bold')
lineTK, = ax3.plot(df2.time, df2.model, color= 'b') 
ax3.plot(df2.time, df2.upCI, color= 'b', linestyle= ':') 
ax3.plot(df2.time, df2.lowCI, color= 'b', linestyle= ':')
ax3.fill_between(df2.time, df2.upCI, df2.lowCI, color= 'b', alpha = 0.1)

#TK-T
lineTK_T, =ax3.plot(df8.time, df8.model, color= 'r', label='TK-T') 
ax3.plot(df8.time, df8.upCI, color= 'r', linestyle= ':') 
ax3.plot(df8.time, df8.lowCI, color= 'r', linestyle= ':') 
ax3.fill_between(df8.time, df8.upCI, df8.lowCI, color= 'red', alpha = 0.1)
ax3.legend((lineTK, lineTK_T),('TK-stan', 'TK-T') ,loc = 1)

#Raw data
ax3.set_title('24 '+u'\u00B0'+'C')
ax3.errorbar(data_IMI_24.time, data_IMI_24.rep1, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax3.errorbar(data_IMI_24.time, data_IMI_24.rep2, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax3.errorbar(data_IMI_24.time, data_IMI_24.rep3, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax3.vlines(1.99, ymin=0, ymax=140, colors='gray', linestyles='solid', label='') # Vertical line to highlight transition from uptake to elimination phase

###############################################################################################################################

###############################################################################################################################
### FPF Models
#7
#TK-Standard
ax4.text(0, 130,'B1', fontsize = 15, weight = 'bold')
ax4.plot(df3.time, df3.model, color= 'b') 
ax4.plot(df3.time, df3.upCI, color= 'b', linestyle= ':') 
ax4.plot(df3.time, df3.lowCI, color= 'b', linestyle= ':')
ax4.fill_between(df3.time, df3.upCI, df3.lowCI, color= 'b', alpha = 0.1)

#TK-T
ax4.plot(df9.time, df9.model, color= 'r') 
ax4.plot(df9.time, df9.upCI, color= 'r', linestyle= ':') 
ax4.plot(df9.time, df9.lowCI, color= 'r', linestyle= ':') 
ax4.fill_between(df9.time, df9.upCI, df9.lowCI, color= 'red', alpha = 0.1)

#Raw data
ax4.errorbar(data_FPF_07.time, data_FPF_07.rep1, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax4.errorbar(data_FPF_07.time, data_FPF_07.rep2, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax4.errorbar(data_FPF_07.time, data_FPF_07.rep3, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax4.vlines(2.03, ymin=0, ymax=100, colors='gray', linestyles='solid', label='') # Vertical line to highlight transition from uptake to elimination phase

#18
#TK-Standard
ax5.text(0, 130,'B2', fontsize = 15, weight = 'bold')
ax5.plot(df4.time, df4.model, color= 'b') 
ax5.plot(df4.time, df4.upCI, color= 'b', linestyle= ':') 
ax5.plot(df4.time, df4.lowCI, color= 'b', linestyle= ':')
ax5.fill_between(df4.time, df4.upCI, df4.lowCI, color= 'b', alpha = 0.1)

#TK-T
ax5.plot(df10.time, df10.model, color= 'r') 
ax5.plot(df10.time, df10.upCI, color= 'r', linestyle= ':') 
ax5.plot(df10.time, df10.lowCI, color= 'r', linestyle= ':') 
ax5.fill_between(df10.time, df10.upCI, df10.lowCI, color= 'red', alpha = 0.1)

ax5.errorbar(data_FPF_18.time, data_FPF_18.rep1, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax5.errorbar(data_FPF_18.time, data_FPF_18.rep2, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax5.errorbar(data_FPF_18.time, data_FPF_18.rep3, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax5.vlines(1.92, ymin=0, ymax=100, colors='gray', linestyles='solid', label='') # Vertical line to highlight transition from uptake to elimination phase

#24
#TK-Standard
ax6.text(0, 130,'B3', fontsize = 15, weight = 'bold')
ax6.plot(df5.time, df5.model, color= 'b') 
ax6.plot(df5.time, df5.upCI, color= 'b', linestyle= ':') 
ax6.plot(df5.time, df5.lowCI, color= 'b', linestyle= ':')
ax6.fill_between(df5.time, df5.upCI, df5.lowCI, color= 'b', alpha = 0.1)

#TK-T
ax6.plot(df11.time, df11.model, color= 'r') 
ax6.plot(df11.time, df11.upCI, color= 'r', linestyle= ':') 
ax6.plot(df11.time, df11.lowCI, color= 'r', linestyle= ':')
ax6.fill_between(df11.time, df11.upCI, df11.lowCI, color= 'red', alpha = 0.1)

ax6.errorbar(data_FPF_24.time, data_FPF_24.rep1, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax6.errorbar(data_FPF_24.time, data_FPF_24.rep2, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax6.errorbar(data_FPF_24.time, data_FPF_24.rep3, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax6.vlines(1.97, ymin=0, ymax=100, colors='gray', linestyles='solid', label='') # Vertical line to highlight transition from uptake to elimination phase

plt.savefig("20220809_TKstandardvsTK-T.pdf")
plt.savefig("20220809_TKstandardvsTK-T.svg")
